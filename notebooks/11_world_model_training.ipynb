# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
try:
    import torch  # type: ignore[import]
    import torch.nn as nn  # type: ignore[import]
    from torch.utils.data import TensorDataset, DataLoader, random_split  # type: ignore[import]
except ImportError as exc:
    raise ImportError(
        "PyTorch is required for this notebook. Please install torch."
    ) from exc
try:
    from sklearn.preprocessing import MinMaxScaler  # type: ignore[import]
except ImportError as exc:
    raise ImportError(
        "scikit-learn is required for this notebook. Please install scikit-learn."
    ) from exc

torch.manual_seed(42)

import sys
root_dir = os.path.abspath("..")
if root_dir not in sys.path:
    sys.path.append(root_dir)
# print("Project root in sys.path:", root_dir)

from src.config import (
    CMAPSS_DATASETS,
    MAX_RUL,
    SEQUENCE_LENGTH,
    HIDDEN_SIZE,
    NUM_LAYERS,
    OUTPUT_SIZE,
    LEARNING_RATE,
    NUM_EPOCHS,
    GLOBAL_FEATURE_COLS,
    GLOBAL_DROP_COLS 
)

from src.data_loading import load_cmapps_subset
from src.additional_features import create_physical_features
from src.world_model_training import train_world_model_global

# %%
import importlib
import src.world_model_training as wmt
importlib.reload(wmt)

from src.data_loading import load_cmapps_global
from src.additional_features import create_physical_features
from src.config import GLOBAL_FEATURE_COLS, GLOBAL_DROP_COLS
from src.world_model_training import(
    build_eol_tail_samples_from_df,
    create_tail_dataloaders,
    train_tail_eol,
    verify_engine_based_split,
    )
import src.models.world_model as wmt
importlib.reload(wmt)
from src.models.world_model import WorldModelEncoderDecoderMultiTaskV9

# Device setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# 1) globale Trainingsdaten bauen (Pseudo-Code, an deine Signaturen anpassen)
dfs = []
for fd_id in ["FD001","FD002", "FD003", "FD004"]: #, "FD002", "FD003", "FD004"
    df_train, _, _ = load_cmapps_subset(
        fd_id,
        max_rul=None,       # oder max_rul=125, clip_train=False
        clip_train=False,   # KEIN Clipping im Train
        clip_test=True,     # Test gerne weiter clampen für NASA-Score
    )
    df_train = create_physical_features(df_train)
    df_train["FD_ID"] = fd_id
    dfs.append(df_train)

df_train_global = pd.concat(dfs, ignore_index=True)

# 2) Featureliste definieren (wie beim globalen LSTM)
numeric_cols = df_train_global[GLOBAL_FEATURE_COLS].select_dtypes(
    include=["number"]
).columns.tolist()
feature_cols = numeric_cols

# Samples bauen (gibt jetzt X, y, unit_ids zurück für engine-basierten Split)
X_tail, y_tail, unit_ids_tail = build_eol_tail_samples_from_df(
    df=df_train_global,
    feature_cols=feature_cols,
    past_len=30,
    max_rul_tail=125,  # Nur Sequenzen mit End-RUL <= 125
    unit_col="UnitNumber",
    cycle_col="TimeInCycles",
    rul_col="RUL",
)

# WICHTIG: Engine-basierter Split um Daten-Leakage zu vermeiden
train_loader, val_loader = create_tail_dataloaders(
    X=X_tail,
    y=y_tail,
    val_ratio=0.2,
    batch_size=128,
    random_seed=42,
    unit_ids=unit_ids_tail,  # Für engine-basierten Split
    engine_based_split=True,  # WICHTIG: Verhindert Daten-Leakage
)

# Verifikation: Prüfe explizit, ob engine-basierter Split verwendet wurde
print("\n" + "=" * 60)
print("VERIFIKATION: Engine-basierter Split")
print("=" * 60)
verification = verify_engine_based_split(
    train_loader=train_loader,
    val_loader=val_loader,
    unit_ids=unit_ids_tail,
)
print("\n" + "=" * 60)
print("VERIFIKATIONS-ERGEBNIS:")
print("=" * 60)
print(f"Status: {verification['verification_status']}")
print(f"Split-Type: {verification['split_type']}")
if verification.get('has_data_leakage') is False:
    print("✓ KEINE Daten-Leakage - Val-Scores sind realistisch und unit-basiert")
elif verification.get('has_data_leakage') is True:
    print("⚠️  WARNUNG: Daten-Leakage erkannt - Val-Scores könnten zu optimistisch sein")
print("=" * 60)

# 3. Modell trainieren
model_tail, history_tail = train_tail_eol(
    train_loader=train_loader,
    val_loader=val_loader,
    seq_len=30,
    num_features=len(feature_cols),
    hidden_dim=128,
    device=device,
    num_epochs=100,
    lr=1e-4,  # Konservativer Default
    weight_decay=1e-4,  # L2-Regularisierung
    dropout=0.1,  # Geringes Dropout
    use_feature_scaling=True,  # Feature-Normalisierung (empfohlen)
    early_stopping_patience=8,  # Early Stopping
    use_lr_scheduler=True,  # LR Scheduler
    checkpoint_dir="../results/tail_eol_mlp",  # Optional: Checkpoint speichern
)
# Out:
# Using device: cpu
# New columns successfully added. Current number of columns: 33
#    Effizienz_HPC_Proxy  EGT_Drift  Fan_HPC_Ratio  RUL
# 0             0.941013        0.2       0.403737  191
# 1             0.943169        0.2       0.403406  190
# 2             0.942554       -1.8       0.404505  189
# 3             0.943025        0.2       0.405834  188
# 4             0.942581        1.2       0.405831  187
# [ConditionID] Found 7 unique (S1_r, S2_r, S3_r) combos in TRAIN.
# [ConditionID] Train ConditionIDs: [0 1 2 3 4 5 6]
# [ConditionID] Test  ConditionIDs: [0 1 2 3 4 5 6]
# New columns successfully added. Current number of columns: 33
#    Effizienz_HPC_Proxy  EGT_Drift  Fan_HPC_Ratio  RUL
# 0             0.940506        6.8       0.408741  148
# 1             0.941593        2.8       0.406364  147
# 2             0.934608      -18.2       0.427536  146
# 3             0.944099        1.8       0.405833  145
# 4             0.938646      -18.2       0.427022  144
# New columns successfully added. Current number of columns: 33
#    Effizienz_HPC_Proxy  EGT_Drift  Fan_HPC_Ratio  RUL
# 0             0.942849       -0.6       0.405728  258
# 1             0.942061        0.4       0.405442  257
# 2             0.941562       -0.6       0.405839  256
# 3             0.941067        0.4       0.405472  255
# 4             0.942027        0.4       0.403920  254
# [ConditionID] Found 7 unique (S1_r, S2_r, S3_r) combos in TRAIN.
# [ConditionID] Train ConditionIDs: [0 1 2 3 4 5 6]
# [ConditionID] Test  ConditionIDs: [0 1 2 3 4 5 6]
# New columns successfully added. Current number of columns: 33
#    Effizienz_HPC_Proxy  EGT_Drift  Fan_HPC_Ratio  RUL
# 0             0.944817       -3.6       0.409162  320
# 1             0.941253       27.4       0.410169  319
# 2             0.938052       -4.6       0.408713  318
# 3             0.940716       -5.6       0.409099  317
# 4             0.938737      -28.6       0.427093  316
# ============================================================
# [build_eol_tail_samples_from_df] Summary
# ============================================================
# Num units: 260
# Using past_len=30, max_rul_tail=125
# Num feature cols: 24
# X shape: torch.Size([89230, 30, 24]), y shape: torch.Size([89230]), unit_ids shape: torch.Size([89230])
# RUL stats (tail): min=0.00, max=125.00, mean=62.43, std=36.34
# ============================================================
# ============================================================
# [EOL-Tail] Engine-based split
# ============================================================
# Total units: 260
# Train units: 208, Val units: 52
# Train samples: 70720, Val samples: 18510
# ============================================================
#
# ============================================================
# VERIFIKATION: Engine-basierter Split
# ============================================================
# ============================================================
# [Engine-Based Split Verification]
# ============================================================
# [INFO] TensorDataset detected - checking via sample extraction...
# [INFO] TensorDataset structure suggests engine-based split was used.
# [INFO] To verify: Check that train and val datasets have different unit distributions.
# Train dataset size: 70720
# Val dataset size: 18510
# Total samples: 89230
# Total unique units in original data: 260
# Train/Total ratio: 79.26%
#
# [VERIFICATION]
# ============================================================
# ✓ TensorDataset structure detected
# ✓ This indicates engine_based_split=True was used in create_tail_dataloaders
# ✓ No data leakage should occur (engines are split, not windows)
# ============================================================
#
# ============================================================
# VERIFIKATIONS-ERGEBNIS:
# ============================================================
# Status: PASSED - Engine-based split confirmed
# Split-Type: engine-based (TensorDataset)
# ✓ KEINE Daten-Leakage - Val-Scores sind realistisch und unit-basiert
# ============================================================
# ============================================================
# [EOL-Tail] Fitting feature scaler on training data...
# ============================================================
# [EOL-Tail] Feature scaler fitted: mean shape=(24,), std shape=(24,)
# ============================================================
# ============================================================
# [EOL-Tail] Training Configuration
# ============================================================
# Learning Rate: 0.0001
# Weight Decay: 0.0001
# Dropout: 0.1
# Feature Scaling: True
# Early Stopping Patience: 8
# LR Scheduler: True
# ============================================================
# [EOL-Tail] Baseline (mean predictor)
# ============================================================
# Mean RUL: 62.43, Baseline RMSE: 36.34
# ============================================================
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 1/100 - train_loss: 3234.58, val_loss: 2156.02, val_RMSE: 46.49, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 2/100 - train_loss: 1597.97, val_loss: 1202.67, val_RMSE: 34.70, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 3/100 - train_loss: 1028.36, val_loss: 922.40, val_RMSE: 30.37, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 4/100 - train_loss: 869.77, val_loss: 836.39, val_RMSE: 28.91, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 5/100 - train_loss: 806.72, val_loss: 802.03, val_RMSE: 28.32, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 6/100 - train_loss: 772.99, val_loss: 781.81, val_RMSE: 27.96, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 7/100 - train_loss: 753.08, val_loss: 766.60, val_RMSE: 27.69, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 8/100 - train_loss: 736.94, val_loss: 755.82, val_RMSE: 27.50, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 9/100 - train_loss: 723.40, val_loss: 742.64, val_RMSE: 27.26, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 10/100 - train_loss: 709.66, val_loss: 733.72, val_RMSE: 27.10, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 11/100 - train_loss: 698.46, val_loss: 727.50, val_RMSE: 26.98, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 12/100 - train_loss: 687.49, val_loss: 713.47, val_RMSE: 26.72, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 13/100 - train_loss: 676.94, val_loss: 708.37, val_RMSE: 26.63, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 14/100 - train_loss: 667.86, val_loss: 698.73, val_RMSE: 26.44, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 15/100 - train_loss: 656.26, val_loss: 693.46, val_RMSE: 26.35, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 16/100 - train_loss: 647.29, val_loss: 687.48, val_RMSE: 26.23, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 17/100 - train_loss: 638.48, val_loss: 671.32, val_RMSE: 25.92, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 18/100 - train_loss: 627.11, val_loss: 669.20, val_RMSE: 25.88, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 19/100 - train_loss: 617.98, val_loss: 659.32, val_RMSE: 25.69, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 20/100 - train_loss: 609.07, val_loss: 659.04, val_RMSE: 25.69, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 21/100 - train_loss: 599.09, val_loss: 637.69, val_RMSE: 25.26, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 22/100 - train_loss: 591.27, val_loss: 633.52, val_RMSE: 25.18, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 23/100 - train_loss: 582.43, val_loss: 624.42, val_RMSE: 25.00, lr: 1.00e-04
# [EOL-Tail-MLP] Epoch 24/100 - train_loss: 573.03, val_loss: 625.57, val_RMSE: 25.03, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 25/100 - train_loss: 566.64, val_loss: 614.31, val_RMSE: 24.80, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 26/100 - train_loss: 556.66, val_loss: 612.56, val_RMSE: 24.77, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 27/100 - train_loss: 550.81, val_loss: 597.61, val_RMSE: 24.46, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 28/100 - train_loss: 545.67, val_loss: 591.47, val_RMSE: 24.33, lr: 1.00e-04
# [EOL-Tail-MLP] Epoch 29/100 - train_loss: 540.96, val_loss: 595.04, val_RMSE: 24.40, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 30/100 - train_loss: 533.80, val_loss: 590.63, val_RMSE: 24.31, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 31/100 - train_loss: 528.53, val_loss: 585.80, val_RMSE: 24.22, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 32/100 - train_loss: 525.28, val_loss: 584.66, val_RMSE: 24.19, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 33/100 - train_loss: 519.80, val_loss: 579.61, val_RMSE: 24.09, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 34/100 - train_loss: 514.29, val_loss: 577.31, val_RMSE: 24.04, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 35/100 - train_loss: 512.88, val_loss: 569.10, val_RMSE: 23.86, lr: 1.00e-04
# [EOL-Tail-MLP] Epoch 36/100 - train_loss: 509.97, val_loss: 576.64, val_RMSE: 24.02, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 37/100 - train_loss: 504.29, val_loss: 563.21, val_RMSE: 23.74, lr: 1.00e-04
# [EOL-Tail-MLP] Epoch 38/100 - train_loss: 501.03, val_loss: 564.11, val_RMSE: 23.76, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 39/100 - train_loss: 498.29, val_loss: 561.15, val_RMSE: 23.69, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 40/100 - train_loss: 497.29, val_loss: 560.30, val_RMSE: 23.68, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 41/100 - train_loss: 494.08, val_loss: 556.50, val_RMSE: 23.60, lr: 1.00e-04
# [EOL-Tail-MLP] Epoch 42/100 - train_loss: 491.83, val_loss: 568.45, val_RMSE: 23.85, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 43/100 - train_loss: 488.13, val_loss: 556.41, val_RMSE: 23.60, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 44/100 - train_loss: 487.86, val_loss: 550.11, val_RMSE: 23.46, lr: 1.00e-04
# [EOL-Tail-MLP] Epoch 45/100 - train_loss: 484.89, val_loss: 562.76, val_RMSE: 23.73, lr: 1.00e-04
# [EOL-Tail-MLP] Epoch 46/100 - train_loss: 482.93, val_loss: 552.06, val_RMSE: 23.51, lr: 1.00e-04
# [EOL-Tail-MLP] Epoch 47/100 - train_loss: 480.66, val_loss: 550.84, val_RMSE: 23.48, lr: 1.00e-04
#   [LR-Scheduler] Reduced learning rate from 1.00e-04 to 5.00e-05
# [EOL-Tail-MLP] Epoch 48/100 - train_loss: 478.69, val_loss: 561.87, val_RMSE: 23.71, lr: 1.00e-04
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 49/100 - train_loss: 469.02, val_loss: 544.66, val_RMSE: 23.35, lr: 5.00e-05
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 50/100 - train_loss: 465.17, val_loss: 544.55, val_RMSE: 23.34, lr: 5.00e-05
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 51/100 - train_loss: 465.19, val_loss: 544.09, val_RMSE: 23.34, lr: 5.00e-05
# [EOL-Tail-MLP] Epoch 52/100 - train_loss: 463.66, val_loss: 550.45, val_RMSE: 23.47, lr: 5.00e-05
# [EOL-Tail-MLP] Epoch 53/100 - train_loss: 461.84, val_loss: 549.30, val_RMSE: 23.45, lr: 5.00e-05
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 54/100 - train_loss: 462.43, val_loss: 542.45, val_RMSE: 23.30, lr: 5.00e-05
# [EOL-Tail-MLP] Epoch 55/100 - train_loss: 459.82, val_loss: 547.11, val_RMSE: 23.40, lr: 5.00e-05
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 56/100 - train_loss: 459.62, val_loss: 541.74, val_RMSE: 23.28, lr: 5.00e-05
# [EOL-Tail-MLP] Epoch 57/100 - train_loss: 458.92, val_loss: 543.78, val_RMSE: 23.33, lr: 5.00e-05
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 58/100 - train_loss: 459.54, val_loss: 535.89, val_RMSE: 23.16, lr: 5.00e-05
# [EOL-Tail-MLP] Epoch 59/100 - train_loss: 455.93, val_loss: 539.12, val_RMSE: 23.23, lr: 5.00e-05
# [EOL-Tail-MLP] Epoch 60/100 - train_loss: 456.37, val_loss: 544.64, val_RMSE: 23.35, lr: 5.00e-05
# [EOL-Tail-MLP] Epoch 61/100 - train_loss: 455.30, val_loss: 536.41, val_RMSE: 23.17, lr: 5.00e-05
#   [LR-Scheduler] Reduced learning rate from 5.00e-05 to 2.50e-05
# [EOL-Tail-MLP] Epoch 62/100 - train_loss: 453.85, val_loss: 536.42, val_RMSE: 23.17, lr: 5.00e-05
# [EOL-Tail-MLP] Epoch 63/100 - train_loss: 449.36, val_loss: 536.28, val_RMSE: 23.17, lr: 2.50e-05
# [EOL-Tail-MLP] --> Saved checkpoint to ../results/tail_eol_mlp\tail_eol_mlp_best.pt
# [EOL-Tail-MLP] Epoch 64/100 - train_loss: 446.94, val_loss: 532.39, val_RMSE: 23.08, lr: 2.50e-05
# [EOL-Tail-MLP] Epoch 65/100 - train_loss: 445.91, val_loss: 535.59, val_RMSE: 23.15, lr: 2.50e-05
# [EOL-Tail-MLP] Epoch 66/100 - train_loss: 447.36, val_loss: 538.19, val_RMSE: 23.21, lr: 2.50e-05
# [EOL-Tail-MLP] Epoch 67/100 - train_loss: 445.29, val_loss: 535.63, val_RMSE: 23.15, lr: 2.50e-05
#   [LR-Scheduler] Reduced learning rate from 2.50e-05 to 1.25e-05
# [EOL-Tail-MLP] Epoch 68/100 - train_loss: 443.73, val_loss: 536.46, val_RMSE: 23.17, lr: 2.50e-05
# [EOL-Tail-MLP] Epoch 69/100 - train_loss: 441.99, val_loss: 534.42, val_RMSE: 23.13, lr: 1.25e-05
# [EOL-Tail-MLP] Epoch 70/100 - train_loss: 440.41, val_loss: 535.60, val_RMSE: 23.15, lr: 1.25e-05
# [EOL-Tail-MLP] Epoch 71/100 - train_loss: 441.55, val_loss: 532.35, val_RMSE: 23.08, lr: 1.25e-05
#   [LR-Scheduler] Reduced learning rate from 1.25e-05 to 6.25e-06
# [EOL-Tail-MLP] Epoch 72/100 - train_loss: 440.70, val_loss: 534.03, val_RMSE: 23.12, lr: 1.25e-05
# [EOL-Tail-MLP] Early stopping triggered at epoch 72 (no improvement for 8 epochs).
# [EOL-Tail-MLP] Loaded best model from epoch 64 with val_RMSE=23.08
# ============================================================
# [EOL-Tail-MLP] Results
# ============================================================
# Best val_RMSE: 23.08 (at epoch 64)
# Baseline RMSE: 36.34
# [EOL-Tail-MLP] ✓ Model beats baseline by 13.26 RMSE
# ============================================================

# %%
# ===================================================================
# Konsistenz-Check: Umfassende Analyse des trainierten Modells
# ===================================================================

from src.world_model_training import (
    evaluate_tail_eol_consistency,
    plot_tail_eol_training_curves,
    plot_tail_eol_predictions,
    plot_tail_eol_error_by_rul_bin,
    check_split_consistency,
)

# Scaler aus dem Modell holen (falls vorhanden)
scaler = getattr(model_tail, 'scaler', None)

# Umfassender Konsistenz-Check mit allen Plots
consistency_results = evaluate_tail_eol_consistency(
    model=model_tail,
    train_loader=train_loader,
    val_loader=val_loader,
    history=history_tail,
    scaler=scaler,
    device=device,
    unit_ids=unit_ids_tail,  # Für Split-Consistency-Check
    plot=True,
    save_dir="../results/tail_eol_mlp",  # Optional: Plots speichern
)

# Ergebnisse ausgeben
print("\n" + "=" * 60)
print("KONSISTENZ-CHECK ZUSAMMENFASSUNG")
print("=" * 60)
print(f"✓ Split-Type: {consistency_results['split_check'].get('split_type', 'unknown')}")
if consistency_results['split_check'].get('has_data_leakage') is True:
    print(f"⚠️  WARNUNG: Daten-Leakage erkannt!")
    print(f"   {consistency_results['split_check'].get('overlapping_units', 0)} Engines in Train UND Val")
elif consistency_results['split_check'].get('has_data_leakage') is False:
    print("✓ Keine Daten-Leakage - Split ist engine-basiert")
print(f"✓ Val RMSE: {consistency_results['predictions']['rmse']:.2f} cycles")
print(f"✓ Val MAE: {consistency_results['predictions']['mae']:.2f} cycles")
print(f"✓ Bias: {consistency_results['predictions']['bias']:.2f} cycles")
print(f"✓ R²: {consistency_results['predictions']['r2']:.3f}")
print("=" * 60)
# Out:
# ============================================================
# [EOL-Tail Consistency Check]
# ============================================================
#
# [1] Split Consistency Check
# ------------------------------------------------------------
# ============================================================
# [Split Consistency Check]
# ============================================================
# [INFO] Cannot directly check split consistency from TensorDataset.
# [INFO] If engine_based_split=True was used in create_tail_dataloaders,
# [INFO] the split should be engine-based (no data leakage).
# [INFO] For accurate check, use engine_based_split=True and provide unit_ids.
# ============================================================
#
# [2] Training Curves
# ------------------------------------------------------------
# [Plot] Saved training curves to ../results/tail_eol_mlp\tail_eol_training_curves.png
# [3] Prediction Analysis
# ------------------------------------------------------------
# [Plot] Saved predictions plot to ../results/tail_eol_mlp\tail_eol_predictions.png
# Val RMSE: 23.08 cycles
# Val MAE: 18.15 cycles
# Bias: -0.69 cycles
# R²: 0.597
#
# [4] Error Analysis by RUL Bin
# ------------------------------------------------------------
# ============================================================
# [EOL-Tail] RMSE & MAE per RUL Bin
# ============================================================
# [0,20)       - RMSE:  18.32 cycles, MAE:  13.40 cycles, Samples:  2940
# [20,40)      - RMSE:  22.77 cycles, MAE:  17.73 cycles, Samples:  2940
# [40,60)      - RMSE:  22.10 cycles, MAE:  17.95 cycles, Samples:  2940
# [60,80)      - RMSE:  20.10 cycles, MAE:  16.20 cycles, Samples:  2940
# [80,100)     - RMSE:  20.06 cycles, MAE:  15.26 cycles, Samples:  2940
# [100,125)    - RMSE:  30.21 cycles, MAE:  25.70 cycles, Samples:  3664
# ============================================================
# [Plot] Saved error-by-bin plot to ../results/tail_eol_mlp\tail_eol_error_by_bin.png
# ============================================================
# [EOL-Tail Consistency Check] Summary
# ============================================================
# Split Type: unknown - TensorDataset
# Val RMSE: 23.08 cycles
# Val MAE: 18.15 cycles
# Bias: -0.69 cycles
# R²: 0.597
# ============================================================
#
# ============================================================
# KONSISTENZ-CHECK ZUSAMMENFASSUNG
# ============================================================
# ✓ Split-Type: unknown - TensorDataset
# ✓ Val RMSE: 23.08 cycles
# ✓ Val MAE: 18.15 cycles
# ✓ Bias: -0.69 cycles
# ✓ R²: 0.597
# ============================================================

# %%
# ===================================================================
# Tail-LSTM Training: LSTM-basierter EOL-Regressor
# ===================================================================

from src.world_model_training import (
    build_eol_tail_samples_from_df,
    create_tail_dataloaders,
    train_tail_lstm,
    verify_engine_based_split,
)

# Verwende die gleichen Daten wie für Tail-MLP
# (X_tail, y_tail, unit_ids_tail wurden bereits erstellt)

# WICHTIG: Engine-basierter Split um Daten-Leakage zu vermeiden
train_loader_lstm, val_loader_lstm = create_tail_dataloaders(
    X=X_tail,
    y=y_tail,
    val_ratio=0.2,
    batch_size=128,
    random_seed=42,
    unit_ids=unit_ids_tail,  # Für engine-basierten Split
    engine_based_split=True,  # WICHTIG: Verhindert Daten-Leakage
)

# Verifikation: Prüfe explizit, ob engine-basierter Split verwendet wurde
print("\n" + "=" * 60)
print("VERIFIKATION: Engine-basierter Split (LSTM)")
print("=" * 60)
verification_lstm = verify_engine_based_split(
    train_loader=train_loader_lstm,
    val_loader=val_loader_lstm,
    unit_ids=unit_ids_tail,
)
print("\n" + "=" * 60)
print("VERIFIKATIONS-ERGEBNIS (LSTM):")
print("=" * 60)
print(f"Status: {verification_lstm['verification_status']}")
print(f"Split-Type: {verification_lstm['split_type']}")
if verification_lstm.get('has_data_leakage') is False:
    print("✓ KEINE Daten-Leakage - Val-Scores sind realistisch und unit-basiert")
elif verification_lstm.get('has_data_leakage') is True:
    print("⚠️  WARNUNG: Daten-Leakage erkannt - Val-Scores könnten zu optimistisch sein")
print("=" * 60)

# LSTM-Modell trainieren
model_tail_lstm, history_tail_lstm = train_tail_lstm(
    train_loader=train_loader_lstm,
    val_loader=val_loader_lstm,
    num_features=len(feature_cols),
    hidden_dim=64,
    num_layers=2,
    bidirectional=False,
    device=device,
    num_epochs=80,
    lr=1e-4,
    weight_decay=1e-4,
    dropout=0.1,
    use_feature_scaling=True,  # Feature-Normalisierung (empfohlen)
    early_stopping_patience=8,  # Early Stopping
    use_lr_scheduler=True,  # LR Scheduler
    checkpoint_dir="../results/tail_eol_lstm",  # Optional: Checkpoint speichern
)
